# %%
from chefboost import Chefboost as chef
import pandas as pd
final=pd.read_excel('final_jupyter_no_F.xlsx')
final
final_1=final[['Decision','student_case','Department','CS1','CS2','CS3','IS2','IS3']]
from sklearn.model_selection import train_test_split
final_1_train, final_1_test = train_test_split( final_1, test_size = 0.3, random_state = 0)

# %%
if __name__ == '__main__':
   config_C5_91 = {'algorithm': 'C4.5', 'enableParallelism': False,'random_state':1}
   model_C5_91 = chef.fit(final_1_train, config_C5_91)
if __name__ == '__main__':
   config_C5_92 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 2}
   model_C5_92 = chef.fit(final_1_train, config_C5_92)
if __name__ == '__main__':
   config_C5_93 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 4}
   model_C5_93 = chef.fit(final_1_train, config_C5_93)
if __name__ == '__main__':
  config_C5_94 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 6}
  model_C5_94 = chef.fit(final_1_train, config_C5_94)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# C4.5  tree is going to be built...
# -------------------------
# finished in  7.922680377960205  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  95.04132231404958 % on  121  instances
# Labels:  ['C' 'A' 'B' 'D']
# Confusion matrix:  [[14, 0, 0, 0], [0, 29, 1, 0], [1, 4, 68, 0], [0, 0, 0, 4]]
# Decision  C  => Accuray:  99.1736 %, Precision:  100.0 %, Recall:  93.3333 %, F1:  96.5517 %
# Decision  A  => Accuray:  95.8678 %, Precision:  96.6667 %, Recall:  87.8788 %, F1:  92.0635 %
# Decision  B  => Accuray:  95.0413 %, Precision:  93.1507 %, Recall:  98.5507 %, F1:  95.7746 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# ...

# %%
if __name__ == '__main__':
   config_C5_81 = {'algorithm': 'CART', 'enableParallelism': False,'random_state':1}
   model_C5_81 = chef.fit(final_1_train, config_C5_81)
if __name__ == '__main__':
   config_C5_82 = {'algorithm': 'CART', 'enableParallelism': True,'random_state':1,'num_cores': 2}
   model_C5_82 = chef.fit(final_1_train, config_C5_82)
if __name__ == '__main__':
   config_C5_83 = {'algorithm': 'CART', 'enableParallelism': True,'random_state':1,'num_cores': 4}
   model_C5_83 = chef.fit(final_1_train, config_C5_83)
if __name__ == '__main__':
  config_C5_84 = {'algorithm': 'CART', 'enableParallelism': True,'random_state':1,'num_cores': 6}
  model_C5_84 = chef.fit(final_1_train, config_C5_84)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# CART  tree is going to be built...
# -------------------------
# finished in  8.932673931121826  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  95.04132231404958 % on  121  instances
# Labels:  ['C' 'A' 'B' 'D']
# Confusion matrix:  [[14, 0, 0, 0], [0, 29, 1, 0], [1, 4, 68, 0], [0, 0, 0, 4]]
# Decision  C  => Accuray:  99.1736 %, Precision:  100.0 %, Recall:  93.3333 %, F1:  96.5517 %
# Decision  A  => Accuray:  95.8678 %, Precision:  96.6667 %, Recall:  87.8788 %, F1:  92.0635 %
# Decision  B  => Accuray:  95.0413 %, Precision:  93.1507 %, Recall:  98.5507 %, F1:  95.7746 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  2 CPU cores will be allocated in parallel running
# CART  tree is going to be built...
# ...

# %%
if __name__ == '__main__':
   config_C5_71 = {'algorithm': 'CHAID', 'enableParallelism': False,'random_state':1}
   model_C5_71 = chef.fit(final_1_train, config_C5_71)
if __name__ == '__main__':
   config_C5_72 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 2}
   model_C5_72 = chef.fit(final_1_train, config_C5_72)
if __name__ == '__main__':
   config_C5_73 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 4}
   model_C5_73 = chef.fit(final_1_train, config_C5_73)
if __name__ == '__main__':
  config_C5_74 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 6}
  model_C5_74 = chef.fit(final_1_train, config_C5_74)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# CHAID  tree is going to be built...
# -------------------------
# finished in  7.7842206954956055  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  95.04132231404958 % on  121  instances
# Labels:  ['C' 'A' 'B' 'D']
# Confusion matrix:  [[14, 0, 0, 0], [0, 29, 1, 0], [1, 4, 68, 0], [0, 0, 0, 4]]
# Decision  C  => Accuray:  99.1736 %, Precision:  100.0 %, Recall:  93.3333 %, F1:  96.5517 %
# Decision  A  => Accuray:  95.8678 %, Precision:  96.6667 %, Recall:  87.8788 %, F1:  92.0635 %
# Decision  B  => Accuray:  95.0413 %, Precision:  93.1507 %, Recall:  98.5507 %, F1:  95.7746 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  2 CPU cores will be allocated in parallel running
# CHAID  tree is going to be built...
# ...

# %%
if __name__ == '__main__':
   config_C5_01 = {'algorithm': 'C4.5', 'enableParallelism': False,'random_state':1}
   model_C5_01 = chef.fit(final_1_test, config_C5_01)
if __name__ == '__main__':
   config_C5_02 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 2}
   model_C5_02 = chef.fit(final_1_test, config_C5_02)
if __name__ == '__main__':
   config_C5_03 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 4}
   model_C5_03 = chef.fit(final_1_test, config_C5_03)
if __name__ == '__main__':
  config_C5_04 = {'algorithm': 'C4.5', 'enableParallelism': True,'random_state':1,'num_cores': 6}
  model_C5_04 = chef.fit(final_1_test, config_C5_04)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# C4.5  tree is going to be built...
# -------------------------
# finished in  3.087902307510376  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  96.22641509433963 % on  53  instances
# Labels:  ['B' 'A' 'C' 'D']
# Confusion matrix:  [[23, 1, 1, 0], [0, 17, 0, 0], [0, 0, 10, 0], [0, 0, 0, 1]]
# Decision  B  => Accuray:  96.2264 %, Precision:  92.0 %, Recall:  100.0 %, F1:  95.8333 %
# Decision  A  => Accuray:  98.1132 %, Precision:  100.0 %, Recall:  94.4444 %, F1:  97.1428 %
# Decision  C  => Accuray:  98.1132 %, Precision:  100.0 %, Recall:  90.9091 %, F1:  95.2381 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  2 CPU cores will be allocated in parallel running
# C4.5  tree is going to be built...
# ...

# %%
if __name__ == '__main__':
   config_C5_11 = {'algorithm': 'CHAID', 'enableParallelism': False,'random_state':1}
   model_C5_11 = chef.fit(final_1_test, config_C5_11)
if __name__ == '__main__':
   config_C5_12 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 2}
   model_C5_12 = chef.fit(final_1_test, config_C5_12)
if __name__ == '__main__':
   config_C5_13 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 4}
   model_C5_13 = chef.fit(final_1_test, config_C5_13)
if __name__ == '__main__':
  config_C5_14 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 6}
  model_C5_14 = chef.fit(final_1_test, config_C5_14)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# CHAID  tree is going to be built...
# -------------------------
# finished in  3.960116147994995  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  96.22641509433963 % on  53  instances
# Labels:  ['B' 'A' 'C' 'D']
# Confusion matrix:  [[23, 1, 1, 0], [0, 17, 0, 0], [0, 0, 10, 0], [0, 0, 0, 1]]
# Decision  B  => Accuray:  96.2264 %, Precision:  92.0 %, Recall:  100.0 %, F1:  95.8333 %
# Decision  A  => Accuray:  98.1132 %, Precision:  100.0 %, Recall:  94.4444 %, F1:  97.1428 %
# Decision  C  => Accuray:  98.1132 %, Precision:  100.0 %, Recall:  90.9091 %, F1:  95.2381 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  2 CPU cores will be allocated in parallel running
# CHAID  tree is going to be built...
# ...

# %%
if __name__ == '__main__':
  config_C5_75 = {'algorithm': 'CHAID', 'enableParallelism': True,'random_state':1,'num_cores': 8}
  model_C5_75 = chef.fit(final_1_train, config_C5_75)
# Out:
# ['student_case', 'Department', 'CS1', 'CS2', 'CS3', 'IS2', 'IS3', 'Decision']
# [INFO]:  8 CPU cores will be allocated in parallel running
# CHAID  tree is going to be built...
# -------------------------
# finished in  4.98461651802063  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  95.04132231404958 % on  121  instances
# Labels:  ['C' 'A' 'B' 'D']
# Confusion matrix:  [[14, 0, 0, 0], [0, 32, 4, 0], [1, 1, 65, 0], [0, 0, 0, 4]]
# Decision  C  => Accuray:  99.1736 %, Precision:  100.0 %, Recall:  93.3333 %, F1:  96.5517 %
# Decision  A  => Accuray:  95.8678 %, Precision:  88.8889 %, Recall:  96.9697 %, F1:  92.7536 %
# Decision  B  => Accuray:  95.0413 %, Precision:  97.0149 %, Recall:  94.2029 %, F1:  95.5882 %
# Decision  D  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
